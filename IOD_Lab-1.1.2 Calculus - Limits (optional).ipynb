# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Calculus - Limits

# %%
import numpy as np
import matplotlib.pyplot as plt

# get matplot to show charts inline
# %matplotlib inline

# %%
# define a function, say f(x) = 1/x
def f(x):
    return 1/x

# %%
# calculate value of f(x) for some values
print('f(4) = ',f(4))
# Out:
# f(4) =  0.25

# %%
# calculate value of f(x) for 0
print('f(0) = ', f(0))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24364\1206349777.py in <module>
#       1 # calculate value of f(x) for 0
# ----> 2 print('f(0) = ', f(0))
#
# ~\AppData\Local\Temp\ipykernel_24364\1492866876.py in f(x)
#       1 # define a function, say f(x) = 1/x
#       2 def f(x):
# ----> 3     return 1/x
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Plot y versus x as lines and/or markers.
#
# > matplotlib.pyplot.plot
#
# [matplotlib.pyplot.plot](https://matplotlib.org/3.1.0/api/_as_gen/matplotlib.pyplot.plot.html)

# %%
# plot f(x) from a small number to a large number
x = np.arange(0.1,100,1)
y = f(x)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.show()

# %% [markdown]
# Plot f(x) from a small number to a large number with logarithmic scale.
#
# > Hint: plt.yscale('log')

# %%
# plot f(x) from a small number to a large number with logarithmic scale
x = np.arange(0.1,100,1)
y = f(x)
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.yscale('log')
plt.grid()
plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
