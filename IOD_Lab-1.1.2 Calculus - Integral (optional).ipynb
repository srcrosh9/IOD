# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Calculus - Integral

# %%
import numpy as np
import matplotlib.pyplot as plt
# get matplot to show charts inline
# %matplotlib inline

# %%
# define a function such as f(x) = x**2
def f(x):
    return x**2

# %%
# plot f(x)
x = np.arange(-10, 11, 1)
y = f(x)

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('f(x)')

plt.show();

# %%
# test the function you defined above by simply print its value for some numbers
print('f(2) = ', f(2))
print('f(5) = ', f(5))
print('f(-3) = ', f(-3))
# Out:
# f(2) =  4
# f(5) =  25
# f(-3) =  9

# %%
# define integral of f(x)
# integral of a function is the area under the curve of this function
# it can be approximated by plotting lots of rectangles and add their areas
# the more rectangles you draw, the better is the approximation
# but why do it by hand where python can do a much better job?!
def integral(startX, endX, numberOfRectangles):
    width = endX - startX / numberOfRectangles
    totalArea = 0
    for i in range(numberOfRectangles):
        height = f(x)
        area = width * height
        totalArea += area
    return totalArea

# %%
# calculate integral of f(x) for some startX, endX and a number of rectangles
print('integral(2.0,4.0,10) = ',integral(2.0,4.0,10))
print('integral(2.0,4.0,1000) = ',integral(2.0,4.0,1000))
print('-----')
print('integral(-1.0,2.0,10) = ',integral(-1.0,2.0,10))
print('integral(-1.0,2.0,1000) = ',integral(-1.0,2.0,1000))
# Out:
# integral(2.0,4.0,10) =  [3800. 3078. 2432. 1862. 1368.  950.  608.  342.  152.   38.    0.   38.
#   152.  342.  608.  950. 1368. 1862. 2432. 3078. 3800.]
# integral(2.0,4.0,1000) =  [399799.99999999 323837.99999999 255872.         195902.
#  143928.          99950.          63968.          35982.
#   15992.           3998.              0.           3998.
#   15992.          35982.          63968.          99950.
#  143928.         195902.         255872.         323837.99999999
#  399799.99999999]
# -----
# integral(-1.0,2.0,10) =  [2100. 1701. 1344. 1029.  756.  525.  336.  189.   84.   21.    0.   21.
#    84.  189.  336.  525.  756. 1029. 1344. 1701. 2100.]
# integral(-1.0,2.0,1000) =  [200100. 162081. 128064.  98049.  72036.  50025.  32016.  18009.   8004.
#    2001.      0.   2001.   8004.  18009.  32016.  50025.  72036.  98049.
#  128064. 162081. 200100.]

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
